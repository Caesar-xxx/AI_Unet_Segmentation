# %%
# 预处理

# %%
# 预处理步骤
# 1.读取NIFTI格式的文件，加载其中图片和mask
# 2.显示一层图片（包含mask）
# 3.动态显示整个扫描（显示一个文件的多层图像信息）
# 4.构造归一化、标准化的函数
# 5.预处理所有文件，保存为np文件，存在磁盘
# 6.检查一下存储的np文件是否合格

# %%
# 导入相关包
import nibabel as nib

# %%
# 挑一个文件测试
test_file = './data/imagesTr/la_018.nii.gz'

# 对应的mask标注
test_mask = './data/labelsTr/la_018.nii.gz'

# %%
# nibabel读取图像信息和mask
img = nib.load(test_file)
mask = nib.load(test_mask)

# %%
# 获取其中数据
img_data = img.get_fdata()
mask_data = mask.get_fdata()

# %%
# 查看大小
print(img_data.shape)
print(mask_data.shape)
# Out:
# (320, 320, 122)
# (320, 320, 122)

# %%
# 显示图片
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.imshow(np.rot90(img_data[:,:,80]),cmap='bone')

# %%
plt.imshow(np.rot90(mask_data[:,:,80]),cmap='bone')

# %%
# 将mask和图片绘制在一起
img_display = np.rot90(img_data[:,:,80])
mask_display = np.rot90(mask_data[:,:,80])   
# 将mask_display像素值为0处遮挡起来
mask = np.ma.masked_where(mask_display==0,mask_display)
plt.imshow(img_display,cmap='bone')
plt.imshow(mask,alpha=0.8,cmap='spring')

# %%
#将122层画面合成为动画
from celluloid  import Camera
from IPython.display import HTML
import tqdm

# %%
img_data.shape
# Out:
# (320, 320, 122)

# %%
#遍历每一层图像和mask
fig = plt.figure()
camera = Camera(fig)

for i in tqdm.tqdm( range(img_data.shape[-1]) ):
    
    # 将mask和图片绘制在一起
    img_display = np.rot90(img_data[:,:,i])
    mask_display = np.rot90(mask_data[:,:,i])   
    # 将mask_display像素值为0处遮挡起来
    mask = np.ma.masked_where(mask_display==0,mask_display)
    plt.imshow(img_display,cmap='bone')
    plt.imshow(mask,alpha=0.8,cmap='spring')
    
    plt.axis('off')
    
    camera.snap()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 122/122 [00:00<00:00, 306.46it/s]

# %%
animation = camera.animate()

# %%
# 显示动画
HTML(animation.to_html5_video()) # conda install -c conda-forge ffmpeg
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
img_data.shape
# Out:
# (320, 320, 122)

# %%
img_data.max(),img_data.min()
# Out:
# (2095.0, 0.0)

# %%
# 归一化标准化

# %% [markdown]
# ### 标准化
# $$ x' = \frac{x-mean(x)}{\sigma} $$
# ### 归一化
# $$ x' = \frac{x-min(x)}{max(x)-min(x)} $$

# %%
#标准化
def standardize(data):
    # 计算均值
    mean = data.mean()
    # 计算标准差
    std = np.std(data)
    
    # 计算结果
    standardized = (data - mean) / std
    return standardized


#  归一化
def normalize(data):
    # 计算最大值和最小值
    max_val = data.max()
    min_val = data.min()
    normalized = (data - min_val) / (max_val - min_val)
    return normalized

# %%
test_data  = img_data[:,:,80]

# %%
std = standardize(test_data)

# %%
std.max(),std.min()
# Out:
# (5.628479883541003, -0.6118425303834774)

# %%
normalize(std).max(),normalize(std).min()
# Out:
# (1.0, 0.0)

# %%
# 处理所有文件

# %%
import glob
import os

# %%
# 获取文件列表（图片和标注）

# %%
train_file_list = glob.glob('data/imagesTr/la*')
train_label_list = glob.glob('data/labelsTr/la*')

# %%
len(train_file_list),len(train_label_list)
# Out:
# (20, 20)

# %%
# 遍历每隔文件，每隔文件包含多层图像，保存为np文件
for index,file  in enumerate(train_file_list):
    
    #读取文件和Label
    # 裁剪边缘，最终输出为256 x 256的图片
    # 标准化和归一化
    # 存入文件夹
    
    
    # 读取
    img = nib.load(file)
    mask = nib.load(train_label_list[index])
    
    img_data = img.get_fdata()
    mask_data = img.get_fdata()
    
    # 裁剪边缘
    img_data_crop = img_data[32:-32,32:-32]
    mask_data_crop = mask_data[32:-32,32:-32]
    
    # 标准化和归一化
    std = standardize(img_data_crop)
    normalized = normalize(std)
    
    #rint(normalized.shape)
    
    # 分成训练集和测试集
    if index < 17:
        # 当成训练集
        save_dir = 'processed/train/'
    else:
        # 当成测试集
        save_dir = 'processed/test/'
        
        
    # 遍历一个文件的所有层，每一层单独挑出来存储进文件夹，路径格式：'processed/train/0/img_0.npy','processed/train/0/label_0.npy'
    # train,test 表示训练集和测试集
    # train/0，中的0 表示文件序号
    # img_0.npy，label_0.npy 分别代表该文件的第1层图像以及对应的标注
    
    # 获取层数
    layer_num = normalized.shape[-1]
    # 遍历每一层
    for i in range(layer_num):
        # 获取第i层图像及标注
        layer = normalized[:,:,i]
        mask = mask_data_crop[:,:,i]
        
        # 创建文件夹
        img_dir = save_dir + str(index)
        # 如没有文件夹，则创建
        if not os.path.exists(img_dir):
            os.makedirs(img_dir)
        
        # 保存numpy文件
        np.save(img_dir + '/img_'+str(i), layer )
        np.save(img_dir + '/label_'+str(i), mask )
        
    
    
    
    
    
    
    
    # break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#      11 img = nib.load(file)
#      12 mask = nib.load(train_label_list[index])
# ---> 14 img_data = img.get_fdata()
#      15 mask_data = img.get_fdata()
#      17 # 裁剪边缘
#
# File C:\conda\envs\course_unet_seg\lib\site-packages\nibabel\dataobj_images.py:355, in DataobjImage.get_fdata(self, caching, dtype)
#     351         return self._fdata_cache
#     352 # Always return requested data type
#     353 # For array proxies, will attempt to confine data array to dtype
#     354 # during scaling
# --> 355 data = np.asanyarray(self._dataobj, dtype=dtype)
#     356 if caching == 'fill':
#     357     self._fdata_cache = data
#
# File C:\conda\envs\course_unet_seg\lib\site-packages\nibabel\arrayproxy.py:370, in ArrayProxy.__array__(self, dtype)
#     349 def __array__(self, dtype=None):
#     350     """ Read data from file and apply scaling, casting to ``dtype``
#     351
#     352     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)
#     368         Scaled image data with type `dtype`.
#     369     """
# --> 370     arr = self._get_scaled(dtype=dtype, slicer=())
#     371     if dtype is not None:
#     372         arr = arr.astype(dtype, copy=False)
#
# File C:\conda\envs\course_unet_seg\lib\site-packages\nibabel\arrayproxy.py:337, in ArrayProxy._get_scaled(self, dtype, slicer)
#     335     scl_inter = scl_inter.astype(use_dtype)
#     336 # Read array and upcast as necessary for big slopes, intercepts
# --> 337 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     338 if dtype is not None:
#     339     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File C:\conda\envs\course_unet_seg\lib\site-packages\nibabel\arrayproxy.py:311, in ArrayProxy._get_unscaled(self, slicer)
#     308 if canonical_slicers(slicer, self._shape, False) == \
#     309         canonical_slicers((), self._shape, False):
#     310     with self._get_fileobj() as fileobj, self._lock:
# --> 311         return array_from_file(self._shape,
#     312                                self._dtype,
#     313                                fileobj,
#     314                                offset=self._offset,
#     315                                order=self.order,
#     316                                mmap=self._mmap)
#     317 with self._get_fileobj() as fileobj:
#     318     return fileslice(fileobj,
#     319                      slicer,
#     320                      self._shape,
#    (...)
#     323                      order=self.order,
#     324                      lock=self._lock)
#
# File C:\conda\envs\course_unet_seg\lib\site-packages\nibabel\volumeutils.py:461, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     459 if hasattr(infile, 'readinto'):
#     460     data_bytes = bytearray(n_bytes)
# --> 461     n_read = infile.readinto(data_bytes)
#     462     needs_copy = False
#     463 else:
#
# File C:\conda\envs\course_unet_seg\lib\gzip.py:292, in GzipFile.read(self, size)
#     290     import errno
#     291     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 292 return self._buffer.read(size)
#
# File C:\conda\envs\course_unet_seg\lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File C:\conda\envs\course_unet_seg\lib\gzip.py:501, in _GzipReader.read(self, size)
#     497     if buf == b"":
#     498         raise EOFError("Compressed file ended before the "
#     499                        "end-of-stream marker was reached")
# --> 501 self._add_read_data( uncompress )
#     502 self._pos += len(uncompress)
#     503 return uncompress
#
# File C:\conda\envs\course_unet_seg\lib\gzip.py:506, in _GzipReader._add_read_data(self, data)
#     505 def _add_read_data(self, data):
# --> 506     self._crc = zlib.crc32(data, self._crc)
#     507     self._stream_size = self._stream_size + len(data)
#
# KeyboardInterrupt:

# %%
# 检查一组数据是否合格

# %%
# 解决列表排序问题
from natsort import natsorted # pip install natsort

# %%
img_test =natsorted(  glob.glob('processed/train/15/img*') )
label_test =natsorted( glob.glob('processed/train/15/label*') )

# %%
len(img_test),len(label_test)
# Out:
# (110, 110)

# %%
img_test[:50]
# Out:
# ['processed/train/15\\img_0.npy',
#  'processed/train/15\\img_1.npy',
#  'processed/train/15\\img_2.npy',
#  'processed/train/15\\img_3.npy',
#  'processed/train/15\\img_4.npy',
#  'processed/train/15\\img_5.npy',
#  'processed/train/15\\img_6.npy',
#  'processed/train/15\\img_7.npy',
#  'processed/train/15\\img_8.npy',
#  'processed/train/15\\img_9.npy',
#  'processed/train/15\\img_10.npy',
#  'processed/train/15\\img_11.npy',
#  'processed/train/15\\img_12.npy',
#  'processed/train/15\\img_13.npy',
#  'processed/train/15\\img_14.npy',
#  'processed/train/15\\img_15.npy',
#  'processed/train/15\\img_16.npy',
#  'processed/train/15\\img_17.npy',
#  'processed/train/15\\img_18.npy',
#  'processed/train/15\\img_19.npy',
#  'processed/train/15\\img_20.npy',
#  'processed/train/15\\img_21.npy',
#  'processed/train/15\\img_22.npy',
#  'processed/train/15\\img_23.npy',
#  'processed/train/15\\img_24.npy',
#  'processed/train/15\\img_25.npy',
#  'processed/train/15\\img_26.npy',
#  'processed/train/15\\img_27.npy',
#  'processed/train/15\\img_28.npy',
#  'processed/train/15\\img_29.npy',
#  'processed/train/15\\img_30.npy',
#  'processed/train/15\\img_31.npy',
#  'processed/train/15\\img_32.npy',
#  'processed/train/15\\img_33.npy',
#  'processed/train/15\\img_34.npy',
#  'processed/train/15\\img_35.npy',
#  'processed/train/15\\img_36.npy',
#  'processed/train/15\\img_37.npy',
#  'processed/train/15\\img_38.npy',
#  'processed/train/15\\img_39.npy',
#  'processed/train/15\\img_40.npy',
#  'processed/train/15\\img_41.npy',
#  'processed/train/15\\img_42.npy',
#  'processed/train/15\\img_43.npy',
#  'processed/train/15\\img_44.npy',
#  'processed/train/15\\img_45.npy',
#  'processed/train/15\\img_46.npy',
#  'processed/train/15\\img_47.npy',
#  'processed/train/15\\img_48.npy',
#  'processed/train/15\\img_49.npy']

# %%
#遍历每一层图像和mask
fig = plt.figure()
camera = Camera(fig)

for index,img_file in enumerate(img_test):
    
    # 加载图片
    img_data = np.load(img_file)
    mask_data = np.load(label_test[index])
    
    # 将mask和图片绘制在一起
    img_display = np.rot90(img_data)
    mask_display = np.rot90(mask_data)   
    # 将mask_display像素值为0处遮挡起来
    mask = np.ma.masked_where(mask_display==0,mask_display)
    plt.imshow(img_display,cmap='bone')
    plt.imshow(mask,alpha=0.8,cmap='spring')
    
    plt.axis('off')
    
    camera.snap()

# %%
animation = camera.animate()

# %%
HTML(animation.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
